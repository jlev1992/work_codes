# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Times']})
rc('text', usetex=True)
from matplotlib.pyplot import figure
figure(num=None, figsize=(16, 12), dpi=80, facecolor='w', edgecolor='k')

data=np.loadtxt('phbands_tCBAB_444')

numbands=len(data[0,:])

hsp=[0.0,0.71,2.30,3.49,4.10,np.max(data[:,0])] 
plt.xticks((hsp),('Z','$\Gamma$','R','X','$\Gamma$','V'),fontsize=32)
#hsp=[0.0,0.71,2.30,3.49,4.10,np.max(data[:,0])] tCBAC new
#plt.xticks((hsp),('Z','$\Gamma$','R','X','$\Gamma$','V'),fontsize=32) tCBAC new
#hsp=[0.0,1.0,1.28,1.65,2.4,3.36,4.32,np.max(data[:,0])] 
#plt.xticks((hsp),('$\Gamma$','$\Sigma$','N','S','Z','N','$\Gamma$','X'),fontsize=32)
#hsp=[0.0,1.0,1.28,1.65,2.4,3.36,4.32,np.max(data[:,0])] ## TaAs
#plt.xticks((hsp),('$\Gamma$','$\Sigma$','N','S','Z','N','$\Gamma$','X'),fontsize=32) ## TaAS
#hsp=[0.0,0.71,1.05,1.85,np.max(data[:,0])] # CIAC_444
#plt.xticks((hsp),('G','X','W','G','L'),fontsize=32) #CIAC_444
plt.yticks(fontsize=32)
plt.ylim(((np.min(data[:,1])-2.),(np.max(data[:,numbands-1])+2.)))
plt.ylim(((np.min(data[:,1])-2.),(np.max(data[:,numbands-1])+2.)))
plt.xlim((0,np.max(data[:,0])))
plt.ylabel('Energy (cm$^{-1}$)',fontsize=32)
plt.gca().xaxis.grid(True)

for i in range(1,numbands):
    data[:,i]*=1.0
    #data[:,i]*=0.12398
    plt.plot(data[:,0],data[:,i],color='blue',lw=2)

plt.savefig('tCBAB_444con16_bandfig')

#for i in range(1,numbands)
#for column in data.T:
#  plt.plot(data[:,0], column,color='black',linewidth=1)
